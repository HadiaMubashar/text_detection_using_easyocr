# %%
 # !pip install easyocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 13.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 14.0 MB/s eta 0:00:00
# ...

# %%
import cv2
import easyocr
import matplotlib.pyplot as plt

# %%
reader = easyocr.Reader(['en'], gpu = True)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
def textDetection(imgpath):
  threshold = 0.25

  img = cv2.imread(img_path)
  text_ = reader.readtext(img)

  for t in text_:
    bbox, text, score = t
    print(text)
    if score > threshold:
      cv2.rectangle(img, bbox[0], bbox[2], (0, 255, 0), 2)
      cv2.putText(img, text, bbox[0], cv2.FONT_HERSHEY_COMPLEX, 0.6, (255, 0, 0), 1)

  imgoutput = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  return imgoutput

# %%
img_path = "constructionsign.jpeg"
img = textDetection(img_path)
plt.imshow(img, cmap = 'gray')
plt.show()
# Out:
# UTILITY
# WORK
# AHEAD

# %%
img_path = "test1.png"
img = textDetection(img_path)
plt.imshow(img, cmap = 'gray')
plt.show()
# Out:
# ROAD CLOSED
# TO ALL PEDESTRIAN
# AND BIKE USE

# %%
img_path = "test2.png"
img = textDetection(img_path)
plt.imshow(img, cmap = 'gray')
plt.show()
# Out:
# td
# L
# S5.00 FEE
# PER USAGE
# FOR NON-MEMBERS
# SIGNED HARBOUR SUPERVISOR

# %%
img_path = "test3.png"
img = textDetection(img_path)
plt.imshow(img, cmap = 'gray')
plt.show()
# Out:
# CAUTION
# MAINTAIN
# SOCIAL
# DISTANCING
# AT LEAST
# 6ft.
# DISTANCE FROM OTHERS
